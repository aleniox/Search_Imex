# %%
import WebSearcher as ws
se = ws.SearchEngine()                     # 1. Initialize collector
se.search('election news')                 # 2. Conduct a search
se.parse_serp()                            # 3. Parse search results
se.save_serp(append_to='serps.json')       # 4. Save HTML and metadata
se.save_parsed(append_to='parsed.json')    # 5. Save parsed results

# %%
import core.exhibition_reader as exhibition

results = exhibition.read_priority_exhibitions(r'D:\Search_Imex\AIPT_Global_Defense_Security_Exhibitions_Full_Database.xlsx')

# %%
results

# %%
import agents.priority_exhibition as ag

user_query = "Hệ thống phân tích dữ liệu video"
lines = "\n".join([
    f"{i+1}. {e.name} | Category: {e.category} | Tags: {e.tags}"
    for i, e in enumerate(results)
])

aa = ag.PriorityExhibitionAgent()
result = aa.filter_exhibitions(results, user_query)
result

# %%
import core.exhibitor_finder as ef

Ef = ef.ExhibitorFinder(search_provider="duckduckgo")
find = await Ef.find_exhibitors("UMEX & SimTEX")

# %%
find
# Out:
# ['TUALCOM',
#  'STM',
#  'TURKISH AEROSPACE',
#  'ASELSAN',
#  'BAYKAR',
#  'SEMAİ',
#  'FIRESTAR SYSTEMS',
#  'EDGE',
#  'UST']

# %%
import core.searcher as se
searcher = se.Searcher(provider="duckduckgo")

link = searcher.find_homepage("TUALCOM")

# %%
link
# Out:
# 'https://www.tualcom.com/'

# %%
import core.crawler as crawler

c = crawler.WebCrawler()

await c._crawl_playwright(link)
# Out:
# ''

# %%
find

# %%
len(results)

# %% [markdown]
# ## DISCO
