# %%
import WebSearcher as ws
se = ws.SearchEngine()                     # 1. Initialize collector
se.search('election news')                 # 2. Conduct a search
se.parse_serp()                            # 3. Parse search results
se.save_serp(append_to='serps.json')       # 4. Save HTML and metadata
se.save_parsed(append_to='parsed.json')    # 5. Save parsed results
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import WebSearcher as ws
#       2 se = ws.SearchEngine()                     # 1. Initialize collector
#       3 se.search('election news')                 # 2. Conduct a search
#       4 se.parse_serp()                            # 3. Parse search results
#
# File c:\Users\PC\Downloads\searchs\.venv\Lib\site-packages\WebSearcher\__init__.py:8
#       6 from .locations import download_locations
#       7 from .parsers import parse_serp
# ----> 8 from .searchers import SearchEngine
#       9 from .utils import load_html, load_soup, make_soup
#      11 __all__ = [
#      12     "ClassifyFooter",
#      13     "ClassifyMain",
#    (...)     21     "make_soup",
#      22 ]
#
# File c:\Users\PC\Downloads\searchs\.venv\Lib\site-packages\WebSearcher\searchers.py:15
#      13 from .models.searches import SearchParams
#      14 from .search_methods.requests_searcher import RequestsSearcher
# ---> 15 from .search_methods.selenium_searcher import SeleniumDriver
#      17 WS_VERSION = metadata.version("WebSearcher")
#      20 class SearchEngine:
#
# File c:\Users\PC\Downloads\searchs\.venv\Lib\site-packages\WebSearcher\search_methods\selenium_searcher.py:5
#       2 from datetime import datetime, timezone
#       4 import orjson
# ----> 5 import undetected_chromedriver as uc
#       6 from selenium.common.exceptions import NoSuchElementException
#       7 from selenium.webdriver.common.by import By
#
# File c:\Users\PC\Downloads\searchs\.venv\Lib\site-packages\undetected_chromedriver\__init__.py:44
#      42 from .dprocess import start_detached
#      43 from .options import ChromeOptions
# ---> 44 from .patcher import IS_POSIX
#      45 from .patcher import Patcher
#      46 from .reactor import Reactor
#
# File c:\Users\PC\Downloads\searchs\.venv\Lib\site-packages\undetected_chromedriver\patcher.py:4
#       1 #!/usr/bin/env python3
#       2 # this module is part of undetected_chromedriver
# ----> 4 from distutils.version import LooseVersion
#       5 import io
#       6 import json
#
# ModuleNotFoundError: No module named 'distutils'
